# %%
from bson.objectid import ObjectId

from pymongo import IndexModel, ASCENDING, DESCENDING

import pymongo
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb+srv://alumno:alumno@cluster0.nytnz.mongodb.net")

# %%
client
# Out:
# MongoClient(host=['cluster0-shard-00-01.nytnz.mongodb.net:27017', 'cluster0-shard-00-00.nytnz.mongodb.net:27017', 'cluster0-shard-00-02.nytnz.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-qliuz2-shard-0', ssl=True)

# %%
print(client.list_database_names())
# Out:
# ['blognoticias', 'sample_airbnb', 'sample_analytics', 'sample_geospatial', 'sample_mflix', 'sample_restaurants', 'sample_supplies', 'sample_training', 'sample_weatherdata', 'admin', 'local']

# %%
restaurant = client.sample_restaurants

# %%
restaurant
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.nytnz.mongodb.net:27017', 'cluster0-shard-00-00.nytnz.mongodb.net:27017', 'cluster0-shard-00-02.nytnz.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-qliuz2-shard-0', ssl=True), 'sample_restaurants')

# %%
print(restaurant.list_collection_names())
# Out:
# ['restaurants', 'neighborhoods']

# %%
misdatos = restaurant.restaurants.find()
for datos in misdatos:
    print(datos["cuisine"])
# Out:
# Delicatessen
# Delicatessen
# American
# Jewish/Kosher
# Jewish/Kosher
# Jewish/Kosher
# Hamburgers
# American
# Chinese
# Irish
# Pizza
# Chicken
# American
# American
# Donuts
# Bagels/Pretzels
# American
# American
# Italian
# American
# Delicatessen
# American
# Delicatessen
# Sandwiches/Salads/Mixed Buffet
# Ice Cream, Gelato, Yogurt, Ices
# Ice Cream, Gelato, Yogurt, Ices
# Pizza
# Chinese
# Delicatessen
# Ice Cream, Gelato, Yogurt, Ices
# Chinese
# Chinese
# American
# American
# Hamburgers
# Ice Cream, Gelato, Yogurt, Ices
# American
# American
# American
# Chicken
# American
# American
# American
# American
# Delicatessen
# American
# American
# Delicatessen
# Continental
# American
# Ice Cream, Gelato, Yogurt, Ices
# Delicatessen
# Chinese
# Caribbean
# American
# Italian
# Turkish
# Steak
# Jewish/Kosher
# Bakery
# American
# Bakery
# Delicatessen
# American
# Donuts
# American
# American
# American
# American
# German
# American
# American
# American
# American
# ...

# %%
misdatos = restaurant.restaurants.find({"$and":[{"cuisine":"Pizza"}, {"borough":"Brooklyn"}]})
for datos in misdatos:
    print(datos["name"]," - ", datos["cuisine"], " - ", datos["borough"])
# Out:
# J&V Famous Pizza  -  Pizza  -  Brooklyn
# Armando'S Pizza  -  Pizza  -  Brooklyn
# Smiling Pizza  -  Pizza  -  Brooklyn
# Victoria Pizza  -  Pizza  -  Brooklyn
# J & R Pizza  -  Pizza  -  Brooklyn
# Pizza Wagon  -  Pizza  -  Brooklyn
# Pizza Plus  -  Pizza  -  Brooklyn
# Luigi'S Pizza  -  Pizza  -  Brooklyn
# Royal Pizza  -  Pizza  -  Brooklyn
# Gino'S Pizza  -  Pizza  -  Brooklyn
# Frank'S Pizza Restaurant  -  Pizza  -  Brooklyn
# Pizza Plate  -  Pizza  -  Brooklyn
# Royal King'S Pizza  -  Pizza  -  Brooklyn
# Pizza Nosh  -  Pizza  -  Brooklyn
# Mr. Phil'S Pizza  -  Pizza  -  Brooklyn
# Jentana'S Pizza  -  Pizza  -  Brooklyn
# Lenny'S Pizza  -  Pizza  -  Brooklyn
# Knapp St Pizza Ii  -  Pizza  -  Brooklyn
# Quentin Pizza  -  Pizza  -  Brooklyn
# Jerusalem Pizza  -  Pizza  -  Brooklyn
# Tony'S Pizza  -  Pizza  -  Brooklyn
# Loduca'S Pizza  -  Pizza  -  Brooklyn
# Antonio'S Pizza  -  Pizza  -  Brooklyn
# Benny'S Famous Pizza  -  Pizza  -  Brooklyn
# ...

# %%
misdatos = restaurant.restaurants.find({"cuisine":{"$in":["Delicatessen", "Hamburgers"]}})
for datos in misdatos:
    print(datos["name"]," - ", datos["cuisine"], " - ", datos["borough"])
# Out:
# Wilken'S Fine Food  -  Delicatessen  -  Brooklyn
# Tony'S Deli  -  Delicatessen  -  Queens
# White Castle  -  Hamburgers  -  Brooklyn
# Steve Chu'S Deli & Grocery  -  Delicatessen  -  Queens
# Bagels N Buns  -  Delicatessen  -  Staten Island
# Sal'S Deli  -  Delicatessen  -  Queens
# Wendy'S  -  Hamburgers  -  Brooklyn
# Plaza Bagels & Deli  -  Delicatessen  -  Staten Island
# Bully'S Deli  -  Delicatessen  -  Manhattan
# Nordic Delicacies  -  Delicatessen  -  Brooklyn
# B & M Hot Bagel & Grocery  -  Delicatessen  -  Staten Island
# White Castle  -  Hamburgers  -  Brooklyn
# Burger King  -  Hamburgers  -  Queens
# White Castle  -  Hamburgers  -  Queens
# Burger King  -  Hamburgers  -  Queens
# Mcdonald'S  -  Hamburgers  -  Bronx
# Burger King  -  Hamburgers  -  Brooklyn
# Mcdonald'S  -  Hamburgers  -  Brooklyn
# Mcdonald'S  -  Hamburgers  -  Staten Island
# Mcdonald'S  -  Hamburgers  -  Queens
# Mcdonald'S  -  Hamburgers  -  Queens
# Mcdonald'S  -  Hamburgers  -  Manhattan
# ...

# %%
import re
misdatos = restaurant.restaurants.find()
n_restaurant = []
for datos in misdatos:
    #print(re.search("^[M]\w+", datos["name"]))
    buscar = re.search("[M][c][d][o][a-z]+\'S", datos["name"])
    if buscar != None:
        print(buscar)
# Out:
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# <re.Match object; span=(0, 10), match="Mcdonald'S">
# ...

# %%
misdatos = restaurant.restaurants.find({"name":{"$regex":"[M][c][d][o][a-z]+\'S"}})
for datos in misdatos:
    print(datos["name"]," - ", datos["cuisine"], " - ", datos["borough"])
# Out:
# Mcdonald'S  -  Hamburgers  -  Bronx
# Mcdonald'S  -  Hamburgers  -  Brooklyn
# Mcdonald'S  -  Hamburgers  -  Staten Island
# Mcdonald'S  -  Hamburgers  -  Queens
# Mcdonald'S  -  Hamburgers  -  Queens
# Mcdonald'S  -  Hamburgers  -  Manhattan
# Mcdonald'S  -  Hamburgers  -  Bronx
# Mcdonald'S  -  Hamburgers  -  Brooklyn
# Mcdonald'S  -  Hamburgers  -  Brooklyn
# Mcdonald'S  -  Hamburgers  -  Brooklyn
# Mcdonald'S  -  Hamburgers  -  Queens
# Mcdonald'S  -  Hamburgers  -  Brooklyn
# Mcdonald'S  -  Hamburgers  -  Manhattan
# Mcdonald'S  -  Hamburgers  -  Queens
# Mcdonald'S  -  Hamburgers  -  Queens
# Mcdonald'S  -  Hamburgers  -  Brooklyn
# Mcdonald'S  -  Hamburgers  -  Brooklyn
# Mcdonald'S  -  Hamburgers  -  Bronx
# Mcdonald'S  -  Hamburgers  -  Manhattan
# Mcdonald'S  -  Hamburgers  -  Manhattan
# Mcdonald'S  -  Hamburgers  -  Queens
# Mcdonald'S  -  Hamburgers  -  Bronx
# Mcdonald'S  -  Hamburgers  -  Staten Island
# Mcdonald'S  -  Hamburgers  -  Queens
# ...
